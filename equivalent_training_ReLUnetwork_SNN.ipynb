# %% [markdown]
# <a href="https://colab.research.google.com/github/eujin99/equivalent-training-ReLUnetwork-SNN/blob/main/equivalent_training_ReLUnetwork_SNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/IBM/equivalent-training-ReLUnetwork-SNN.git
# %cd equivalent-training-ReLUnetwork-SNN
# Out:
# Cloning into 'equivalent-training-ReLUnetwork-SNN'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 23 (delta 7), reused 12 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 22.92 KiB | 2.86 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /content/equivalent-training-ReLUnetwork-SNN

# %%
# %cd /content/equivalent-training-ReLUnetwork-SNN

# !python main.py \
  --model_type=SNN \
  --model_name=FC2_example_train \
  --data_name=MNIST \
  --epochs=1
# Out:
# /content/equivalent-training-ReLUnetwork-SNN
# 2025-11-20 01:15:08.428175: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763601308.470615     634 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763601308.479251     634 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763601308.498856     634 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python main.py \
  --model_type=ReLU \
  --model_name=FC2_example \
  --data_name=MNIST \
  --save=True \
  --epochs=1
# Out:
# 2025-11-20 01:18:23.066128: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763601503.096953    1455 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763601503.104717    1455 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763601503.126122    1455 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python main.py \
  --model_type=SNN \
  --model_name=FC2_example \
  --data_name=MNIST \
  --epochs=1 \
  --load=False
# Out:
# 2025-11-20 01:31:59.035052: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763602319.061820    4788 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763602319.074332    4788 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763602319.096709    4788 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python main.py \
  --model_type=SNN \
  --model_name=FC2_example \
  --data_name=MNIST \
  --epochs=10 \
  --load=False
# Out:
# 2025-11-20 01:34:22.929860: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763602462.959024    5405 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763602462.968007    5405 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763602462.992396    5405 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# #### CIFAR10

# %%
# !python main.py \
  --model_type=ReLU \
  --model_name=VGG_BN_example \
  --data_name=CIFAR10 \
  --load=cifar10vgg.h5
# Out:
# 2025-11-20 01:48:39.756577: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763603319.784726    8994 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763603319.793231    8994 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763603319.814929    8994 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python main.py \
  --model_type=SNN \
  --lr=1e-6 \
  --model_name=VGG_BN_example \
  --data_name=CIFAR10 \
  --load=True \
  --epochs=1
